# %%
# !pip install pennylane pennylane-lightning
# Out:
# ...
#    ---------------------------------------- 0.0/5.3 MB ? eta -:--:--
#    ----- ---------------------------------- 0.8/5.3 MB 8.1 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.8/5.3 MB 8.1 MB/s eta 0:00:01
#    ------- -------------------------------- 1.0/5.3 MB 1.5 MB/s eta 0:00:03
#    ----------- ---------------------------- 1.6/5.3 MB 2.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.6/5.3 MB 2.0 MB/s eta 0:00:02
#    ------------------- -------------------- 2.6/5.3 MB 1.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.1/5.3 MB 2.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.1/5.3 MB 2.3 MB/s eta 0:00:01
#    ------------------------------- -------- 4.2/5.3 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 4.5/5.3 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 5.3/5.3 MB 2.1 MB/s eta 0:00:00
# ...
