# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parents[1]

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

print("PROJECT_ROOT:", PROJECT_ROOT)
print("qepc in root?", (PROJECT_ROOT / "qepc").exists())
# Out:
# PROJECT_ROOT: C:\Users\wdors\qepc_project
# qepc in root? True

# %%
import pandas as pd

from qepc.brain.games_loader import fetch_league_games, build_games_table
from qepc.brain.scripts import label_game_scripts_by_total_points

season = "2023-24"

# Team-level game logs (one row per TEAM_ID / GAME_ID)
team_games = fetch_league_games(season)
print("team_games shape:", team_games.shape)
display(team_games.head())

# Game-level table (one row per game)
games_df = build_games_table(team_games)
print("games_df shape:", games_df.shape)
display(games_df.head())

# Script labels for games (we may use later)
scripts_df = label_game_scripts_by_total_points(
    games_df,
    low_quantile=0.25,
    high_quantile=0.75,
)
print("scripts_df shape:", scripts_df.shape)
display(scripts_df.head())
# Out:
# [games_loader] Fetching LeagueGameLog for season=2023-24, season_type=Regular Season...
# [games_loader] Retrieved 2460 team-games.
# team_games shape: (2460, 29)
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0     22023  1610612743               DEN         Denver Nuggets  0022300061
# 1     22023  1610612744               GSW  Golden State Warriors  0022300062
# 2     22023  1610612747               LAL     Los Angeles Lakers  0022300061
# 3     22023  1610612756               PHX           Phoenix Suns  0022300062
# 4     22023  1610612740               NOP   New Orleans Pelicans  0022300071
#
#     GAME_DATE      MATCHUP WL  MIN  FGM  ...  DREB  REB  AST  STL  BLK  TOV  \
# 0  2023-10-24  DEN vs. LAL  W  240   48  ...    33   42   29    9    6   12
# 1  2023-10-24  GSW vs. PHX  L  240   36  ...    31   49   19   11    6   11
# 2  2023-10-24    LAL @ DEN  L  240   41  ...    31   44   23    5    4   12
# 3  2023-10-24    PHX @ GSW  W  240   42  ...    43   60   23    5    7   19
# 4  2023-10-25    NOP @ MEM  W  240   40  ...    41   52   22    8    5   21
#
#    PF  PTS  PLUS_MINUS  VIDEO_AVAILABLE
# 0  15  119          12                1
# 1  23  104          -4                1
# 2  18  107         -12                1
# 3  22  108           4                1
# 4  21  111           7                1
#
# [5 rows x 29 columns]
# games_df shape: (1230, 14)
#       GAME_ID  GAME_DATE SEASON_ID  HOME_TEAM_ID         HOME_TEAM_NAME  \
# 0  0022300061 2023-10-24     22023    1610612743         Denver Nuggets
# 1  0022300062 2023-10-24     22023    1610612744  Golden State Warriors
# 2  0022300070 2023-10-25     22023    1610612741          Chicago Bulls
# 3  0022300074 2023-10-25     22023    1610612746            LA Clippers
# 4  0022300068 2023-10-25     22023    1610612748             Miami Heat
#
#   HOME_TEAM_ABBREVIATION  HOME_PTS  AWAY_TEAM_ID          AWAY_TEAM_NAME  \
# 0                    DEN       119    1610612747      Los Angeles Lakers
# 1                    GSW       104    1610612756            Phoenix Suns
# 2                    CHI       104    1610612760   Oklahoma City Thunder
# 3                    LAC       123    1610612757  Portland Trail Blazers
# 4                    MIA       103    1610612765         Detroit Pistons
#
#   AWAY_TEAM_ABBREVIATION  AWAY_PTS HOME_RESULT  MARGIN  TOTAL_POINTS
# 0                    LAL       107           W      12           226
# 1                    PHX       108           L      -4           212
# 2                    OKC       124           L     -20           228
# 3                    POR       111           W      12           234
# 4                    DET       102           W       1           205
# scripts_df shape: (1230, 8)
#       GAME_ID  GAME_DATE  TOTAL_POINTS   TOTAL_Q SCRIPT_LABEL  SCRIPT_INDEX  \
# 0  0022300061 2023-10-24           226  0.472358     BALANCED             1
# 1  0022300062 2023-10-24           212  0.213821        GRIND             0
# 2  0022300070 2023-10-25           228  0.510976     BALANCED             1
# 3  0022300074 2023-10-25           234  0.623171     BALANCED             1
# 4  0022300068 2023-10-25           205  0.114634        GRIND             0
#
#    TOTAL_Q_LOW  TOTAL_Q_HIGH
# 0        214.0         242.0
# 1        214.0         242.0
# 2        214.0         242.0
# 3        214.0         242.0
# 4        214.0         242.0

# %%
from pathlib import Path

from qepc.brain.boxscores_loader import fetch_boxscores_for_games

data_dir = PROJECT_ROOT / "data" / "raw" / "nba" / "boxscores"
data_dir.mkdir(parents=True, exist_ok=True)

trad_path = data_dir / f"boxscores_traditional_{season}.parquet"

if trad_path.exists():
    print("Loading existing traditional boxscores from:", trad_path)
    trad_df = pd.read_parquet(trad_path)
else:
    print("No parquet found, fetching boxscores from API (this may take a while)...")
    game_ids = games_df["GAME_ID"].unique().tolist()
    trad_df, _ = fetch_boxscores_for_games(game_ids)  # ignore advanced for now

    print("Raw trad_df shape:", trad_df.shape)

    # Basic normalize: ensure column names we care about exist and types are sane
    # (You can extend this if needed; this matches the earlier structure we saw.)
    trad_df["GAME_ID"] = trad_df["GAME_ID"].astype(str)
    trad_df["TEAM_ID"] = trad_df["TEAM_ID"].astype(int)
    trad_df["PLAYER_ID"] = trad_df["PLAYER_ID"].astype(int)

    trad_df.to_parquet(trad_path, index=False)
    print("Saved full-season trad_df to:", trad_path)

print("trad_df shape:", trad_df.shape)
display(trad_df.head())
# Out:
# No parquet found, fetching boxscores from API (this may take a while)...
# [boxscores_loader] (1) Fetching boxscores for GAME_ID=0022300061...
# [boxscores_loader] (2) Fetching boxscores for GAME_ID=0022300062...
# [boxscores_loader] (3) Fetching boxscores for GAME_ID=0022300070...
# [boxscores_loader] (4) Fetching boxscores for GAME_ID=0022300074...
# [boxscores_loader] (5) Fetching boxscores for GAME_ID=0022300068...
# [boxscores_loader] (6) Fetching boxscores for GAME_ID=0022300067...
# [boxscores_loader] (7) Fetching boxscores for GAME_ID=0022300065...
# [boxscores_loader] (8) Fetching boxscores for GAME_ID=0022300066...
# [boxscores_loader] (9) Fetching boxscores for GAME_ID=0022300071...
# [boxscores_loader] (10) Fetching boxscores for GAME_ID=0022300064...
# [boxscores_loader] (11) Fetching boxscores for GAME_ID=0022300073...
# [boxscores_loader] (12) Fetching boxscores for GAME_ID=0022300069...
# [boxscores_loader] (13) Fetching boxscores for GAME_ID=0022300072...
# [boxscores_loader] (14) Fetching boxscores for GAME_ID=0022300063...
# [boxscores_loader] (15) Fetching boxscores for GAME_ID=0022300075...
# [boxscores_loader] (16) Fetching boxscores for GAME_ID=0022300076...
# [boxscores_loader] (17) Fetching boxscores for GAME_ID=0022300079...
# [boxscores_loader] (18) Fetching boxscores for GAME_ID=0022300081...
# [boxscores_loader] (19) Fetching boxscores for GAME_ID=0022300082...
# [boxscores_loader] (20) Fetching boxscores for GAME_ID=0022300084...
# [boxscores_loader] (21) Fetching boxscores for GAME_ID=0022300085...
# [boxscores_loader] (22) Fetching boxscores for GAME_ID=0022300078...
# [boxscores_loader] (23) Fetching boxscores for GAME_ID=0022300080...
# [boxscores_loader] (24) Fetching boxscores for GAME_ID=0022300086...
# [boxscores_loader] (25) Fetching boxscores for GAME_ID=0022300077...
# [boxscores_loader] (26) Fetching boxscores for GAME_ID=0022300087...
# [boxscores_loader] (27) Fetching boxscores for GAME_ID=0022300083...
# [boxscores_loader] (28) Fetching boxscores for GAME_ID=0022300091...
# [boxscores_loader] (29) Fetching boxscores for GAME_ID=0022300090...
# [boxscores_loader] (30) Fetching boxscores for GAME_ID=0022300094...
# [boxscores_loader] (31) Fetching boxscores for GAME_ID=0022300088...
# [boxscores_loader] (32) Fetching boxscores for GAME_ID=0022300093...
# [boxscores_loader] (33) Fetching boxscores for GAME_ID=0022300092...
# [boxscores_loader] (34) Fetching boxscores for GAME_ID=0022300089...
# [boxscores_loader] (35) Fetching boxscores for GAME_ID=0022300096...
# [boxscores_loader] (36) Fetching boxscores for GAME_ID=0022300097...
# [boxscores_loader] (37) Fetching boxscores for GAME_ID=0022300100...
# [boxscores_loader] (38) Fetching boxscores for GAME_ID=0022300095...
# [boxscores_loader] (39) Fetching boxscores for GAME_ID=0022300099...
# [boxscores_loader] (40) Fetching boxscores for GAME_ID=0022300098...
# [boxscores_loader] (41) Fetching boxscores for GAME_ID=0022300110...
# [boxscores_loader] (42) Fetching boxscores for GAME_ID=0022300102...
# [boxscores_loader] (43) Fetching boxscores for GAME_ID=0022300109...
# [boxscores_loader] (44) Fetching boxscores for GAME_ID=0022300105...
# [boxscores_loader] (45) Fetching boxscores for GAME_ID=0022300106...
# [boxscores_loader] (46) Fetching boxscores for GAME_ID=0022300103...
# [boxscores_loader] (47) Fetching boxscores for GAME_ID=0022300101...
# [boxscores_loader] (48) Fetching boxscores for GAME_ID=0022300104...
# [boxscores_loader] (49) Fetching boxscores for GAME_ID=0022300108...
# [boxscores_loader] (50) Fetching boxscores for GAME_ID=0022300111...
# [boxscores_loader] (51) Fetching boxscores for GAME_ID=0022300107...
# [boxscores_loader] (52) Fetching boxscores for GAME_ID=0022300114...
# [boxscores_loader] (53) Fetching boxscores for GAME_ID=0022300112...
# [boxscores_loader] (54) Fetching boxscores for GAME_ID=0022300113...
# [boxscores_loader] (55) Fetching boxscores for GAME_ID=0022300124...
# [boxscores_loader] (56) Fetching boxscores for GAME_ID=0022300119...
# [boxscores_loader] (57) Fetching boxscores for GAME_ID=0022300123...
# [boxscores_loader] (58) Fetching boxscores for GAME_ID=0022300120...
# [boxscores_loader] (59) Fetching boxscores for GAME_ID=0022300116...
# [boxscores_loader] (60) Fetching boxscores for GAME_ID=0022300125...
# [boxscores_loader] (61) Fetching boxscores for GAME_ID=0022300115...
# [boxscores_loader] (62) Fetching boxscores for GAME_ID=0022300118...
# [boxscores_loader] (63) Fetching boxscores for GAME_ID=0022300126...
# [boxscores_loader] (64) Fetching boxscores for GAME_ID=0022300122...
# [boxscores_loader] (65) Fetching boxscores for GAME_ID=0022300127...
# [boxscores_loader] (66) Fetching boxscores for GAME_ID=0022300121...
# [boxscores_loader] (67) Fetching boxscores for GAME_ID=0022300117...
# [boxscores_loader] (68) Fetching boxscores for GAME_ID=0022300128...
# [boxscores_loader] (69) Fetching boxscores for GAME_ID=0022300130...
# [boxscores_loader] (70) Fetching boxscores for GAME_ID=0022300129...
# [boxscores_loader] (71) Fetching boxscores for GAME_ID=0022300131...
# [boxscores_loader] (72) Fetching boxscores for GAME_ID=0022300004...
# [boxscores_loader] (73) Fetching boxscores for GAME_ID=0022300006...
# [boxscores_loader] (74) Fetching boxscores for GAME_ID=0022300003...
# [boxscores_loader] (75) Fetching boxscores for GAME_ID=0022300001...
# [boxscores_loader] (76) Fetching boxscores for GAME_ID=0022300002...
# [boxscores_loader] (77) Fetching boxscores for GAME_ID=0022300007...
# [boxscores_loader] (78) Fetching boxscores for GAME_ID=0022300005...
# [boxscores_loader] (79) Fetching boxscores for GAME_ID=0022300137...
# [boxscores_loader] (80) Fetching boxscores for GAME_ID=0022300138...
# [boxscores_loader] (81) Fetching boxscores for GAME_ID=0022300132...
# [boxscores_loader] (82) Fetching boxscores for GAME_ID=0022300135...
# [boxscores_loader] (83) Fetching boxscores for GAME_ID=0022300139...
# [boxscores_loader] (84) Fetching boxscores for GAME_ID=0022300136...
# [boxscores_loader] (85) Fetching boxscores for GAME_ID=0022300133...
# [boxscores_loader] (86) Fetching boxscores for GAME_ID=0022300134...
# [boxscores_loader] (87) Fetching boxscores for GAME_ID=0022300142...
# [boxscores_loader] (88) Fetching boxscores for GAME_ID=0022300143...
# [boxscores_loader] (89) Fetching boxscores for GAME_ID=0022300141...
# [boxscores_loader] (90) Fetching boxscores for GAME_ID=0022300144...
# [boxscores_loader] (91) Fetching boxscores for GAME_ID=0022300140...
# [boxscores_loader] (92) Fetching boxscores for GAME_ID=0022300152...
# [boxscores_loader] (93) Fetching boxscores for GAME_ID=0022300156...
# [boxscores_loader] (94) Fetching boxscores for GAME_ID=0022300149...
# [boxscores_loader] (95) Fetching boxscores for GAME_ID=0022300147...
# [boxscores_loader] (96) Fetching boxscores for GAME_ID=0022300146...
# [boxscores_loader] (97) Fetching boxscores for GAME_ID=0022300148...
# [boxscores_loader] (98) Fetching boxscores for GAME_ID=0022300155...
# [boxscores_loader] (99) Fetching boxscores for GAME_ID=0022300145...
# [boxscores_loader] (100) Fetching boxscores for GAME_ID=0022300153...
# [boxscores_loader] (101) Fetching boxscores for GAME_ID=0022300150...
# [boxscores_loader] (102) Fetching boxscores for GAME_ID=0022300154...
# [boxscores_loader] (103) Fetching boxscores for GAME_ID=0022300151...
# [boxscores_loader] (104) Fetching boxscores for GAME_ID=0022300159...
# [boxscores_loader] (105) Fetching boxscores for GAME_ID=0022300170...
# [boxscores_loader] (106) Fetching boxscores for GAME_ID=0022300167...
# [boxscores_loader] (107) Fetching boxscores for GAME_ID=0022300164...
# [boxscores_loader] (108) Fetching boxscores for GAME_ID=0022300157...
# [boxscores_loader] (109) Fetching boxscores for GAME_ID=0022300162...
# [boxscores_loader] (110) Fetching boxscores for GAME_ID=0022300168...
# [boxscores_loader] (111) Fetching boxscores for GAME_ID=0022300169...
# [boxscores_loader] (112) Fetching boxscores for GAME_ID=0022300165...
# [boxscores_loader] (113) Fetching boxscores for GAME_ID=0022300160...
# [boxscores_loader] (114) Fetching boxscores for GAME_ID=0022300161...
# [boxscores_loader] (115) Fetching boxscores for GAME_ID=0022300158...
# [boxscores_loader] (116) Fetching boxscores for GAME_ID=0022300163...
# [boxscores_loader] (117) Fetching boxscores for GAME_ID=0022300166...
# [boxscores_loader] (118) Fetching boxscores for GAME_ID=0022300172...
# [boxscores_loader] (119) Fetching boxscores for GAME_ID=0022300171...
# [boxscores_loader] (120) Fetching boxscores for GAME_ID=0022300010...
# [boxscores_loader] (121) Fetching boxscores for GAME_ID=0022300011...
# [boxscores_loader] (122) Fetching boxscores for GAME_ID=0022300015...
# [boxscores_loader] (123) Fetching boxscores for GAME_ID=0022300013...
# [boxscores_loader] (124) Fetching boxscores for GAME_ID=0022300014...
# [boxscores_loader] (125) Fetching boxscores for GAME_ID=0022300016...
# [boxscores_loader] (126) Fetching boxscores for GAME_ID=0022300012...
# [boxscores_loader] (127) Fetching boxscores for GAME_ID=0022300009...
# [boxscores_loader] (128) Fetching boxscores for GAME_ID=0022300008...
# [boxscores_loader] (129) Fetching boxscores for GAME_ID=0022300174...
# [boxscores_loader] (130) Fetching boxscores for GAME_ID=0022300176...
# [boxscores_loader] (131) Fetching boxscores for GAME_ID=0022300175...
# [boxscores_loader] (132) Fetching boxscores for GAME_ID=0022300173...
# [boxscores_loader] (133) Fetching boxscores for GAME_ID=0022300183...
# [boxscores_loader] (134) Fetching boxscores for GAME_ID=0022300181...
# [boxscores_loader] (135) Fetching boxscores for GAME_ID=0022300182...
# [boxscores_loader] (136) Fetching boxscores for GAME_ID=0022300178...
# [boxscores_loader] (137) Fetching boxscores for GAME_ID=0022300180...
# [boxscores_loader] (138) Fetching boxscores for GAME_ID=0022300186...
# [boxscores_loader] (139) Fetching boxscores for GAME_ID=0022300179...
# [boxscores_loader] (140) Fetching boxscores for GAME_ID=0022300187...
# [boxscores_loader] (141) Fetching boxscores for GAME_ID=0022300177...
# [boxscores_loader] (142) Fetching boxscores for GAME_ID=0022300185...
# [boxscores_loader] (143) Fetching boxscores for GAME_ID=0022300184...
# [boxscores_loader] (144) Fetching boxscores for GAME_ID=0022300188...
# [boxscores_loader] (145) Fetching boxscores for GAME_ID=0022300190...
# [boxscores_loader] (146) Fetching boxscores for GAME_ID=0022300189...
# [boxscores_loader] (147) Fetching boxscores for GAME_ID=0022300191...
# [boxscores_loader] (148) Fetching boxscores for GAME_ID=0022300024...
# [boxscores_loader] (149) Fetching boxscores for GAME_ID=0022300025...
# [boxscores_loader] (150) Fetching boxscores for GAME_ID=0022300026...
# [boxscores_loader] (151) Fetching boxscores for GAME_ID=0022300020...
# [boxscores_loader] (152) Fetching boxscores for GAME_ID=0022300019...
# [boxscores_loader] (153) Fetching boxscores for GAME_ID=0022300023...
# [boxscores_loader] (154) Fetching boxscores for GAME_ID=0022300018...
# [boxscores_loader] (155) Fetching boxscores for GAME_ID=0022300022...
# [boxscores_loader] (156) Fetching boxscores for GAME_ID=0022300021...
# [boxscores_loader] (157) Fetching boxscores for GAME_ID=0022300017...
# [boxscores_loader] (158) Fetching boxscores for GAME_ID=0022300193...
# [boxscores_loader] (159) Fetching boxscores for GAME_ID=0022300196...
# [boxscores_loader] (160) Fetching boxscores for GAME_ID=0022300198...
# [boxscores_loader] (161) Fetching boxscores for GAME_ID=0022300199...
# [boxscores_loader] (162) Fetching boxscores for GAME_ID=0022300195...
# [boxscores_loader] (163) Fetching boxscores for GAME_ID=0022300194...
# [boxscores_loader] (164) Fetching boxscores for GAME_ID=0022300197...
# [boxscores_loader] (165) Fetching boxscores for GAME_ID=0022300192...
# [boxscores_loader] (166) Fetching boxscores for GAME_ID=0022300200...
# [boxscores_loader] (167) Fetching boxscores for GAME_ID=0022300201...
# [boxscores_loader] (168) Fetching boxscores for GAME_ID=0022300030...
# [boxscores_loader] (169) Fetching boxscores for GAME_ID=0022300033...
# [boxscores_loader] (170) Fetching boxscores for GAME_ID=0022300036...
# [boxscores_loader] (171) Fetching boxscores for GAME_ID=0022300031...
# [boxscores_loader] (172) Fetching boxscores for GAME_ID=0022300029...
# [boxscores_loader] (173) Fetching boxscores for GAME_ID=0022300034...
# [boxscores_loader] (174) Fetching boxscores for GAME_ID=0022300037...
# [boxscores_loader] (175) Fetching boxscores for GAME_ID=0022300032...
# [boxscores_loader] (176) Fetching boxscores for GAME_ID=0022300035...
# [boxscores_loader] (177) Fetching boxscores for GAME_ID=0022300028...
# [boxscores_loader] (178) Fetching boxscores for GAME_ID=0022300027...
# [boxscores_loader] (179) Fetching boxscores for GAME_ID=0022300204...
# [boxscores_loader] (180) Fetching boxscores for GAME_ID=0022300207...
# [boxscores_loader] (181) Fetching boxscores for GAME_ID=0022300206...
# [boxscores_loader] (182) Fetching boxscores for GAME_ID=0022300202...
# [boxscores_loader] (183) Fetching boxscores for GAME_ID=0022300203...
# [boxscores_loader] (184) Fetching boxscores for GAME_ID=0022300205...
# [boxscores_loader] (185) Fetching boxscores for GAME_ID=0022300212...
# [boxscores_loader] (186) Fetching boxscores for GAME_ID=0022300208...
# [boxscores_loader] (187) Fetching boxscores for GAME_ID=0022300210...
# [boxscores_loader] (188) Fetching boxscores for GAME_ID=0022300216...
# [boxscores_loader] (189) Fetching boxscores for GAME_ID=0022300209...
# [boxscores_loader] (190) Fetching boxscores for GAME_ID=0022300215...
# [boxscores_loader] (191) Fetching boxscores for GAME_ID=0022300211...
# [boxscores_loader] (192) Fetching boxscores for GAME_ID=0022300214...
# [boxscores_loader] (193) Fetching boxscores for GAME_ID=0022300213...
# [boxscores_loader] (194) Fetching boxscores for GAME_ID=0022300222...
# [boxscores_loader] (195) Fetching boxscores for GAME_ID=0022300224...
# [boxscores_loader] (196) Fetching boxscores for GAME_ID=0022300223...
# [boxscores_loader] (197) Fetching boxscores for GAME_ID=0022300217...
# [boxscores_loader] (198) Fetching boxscores for GAME_ID=0022300220...
# [boxscores_loader] (199) Fetching boxscores for GAME_ID=0022300221...
# [boxscores_loader] (200) Fetching boxscores for GAME_ID=0022300219...
# [boxscores_loader] (201) Fetching boxscores for GAME_ID=0022300218...
# [boxscores_loader] (202) Fetching boxscores for GAME_ID=0022300039...
# [boxscores_loader] (203) Fetching boxscores for GAME_ID=0022300038...
# [boxscores_loader] (204) Fetching boxscores for GAME_ID=0022300042...
# [boxscores_loader] (205) Fetching boxscores for GAME_ID=0022300040...
# [boxscores_loader] (206) Fetching boxscores for GAME_ID=0022300041...
# [boxscores_loader] (207) Fetching boxscores for GAME_ID=0022300233...
# [boxscores_loader] (208) Fetching boxscores for GAME_ID=0022300238...
# [boxscores_loader] (209) Fetching boxscores for GAME_ID=0022300232...
# [boxscores_loader] (210) Fetching boxscores for GAME_ID=0022300226...
# [boxscores_loader] (211) Fetching boxscores for GAME_ID=0022300230...
# [boxscores_loader] (212) Fetching boxscores for GAME_ID=0022300236...
# [boxscores_loader] (213) Fetching boxscores for GAME_ID=0022300237...
# [boxscores_loader] (214) Fetching boxscores for GAME_ID=0022300234...
# [boxscores_loader] (215) Fetching boxscores for GAME_ID=0022300227...
# [boxscores_loader] (216) Fetching boxscores for GAME_ID=0022300228...
# [boxscores_loader] (217) Fetching boxscores for GAME_ID=0022300229...
# [boxscores_loader] (218) Fetching boxscores for GAME_ID=0022300231...
# [boxscores_loader] (219) Fetching boxscores for GAME_ID=0022300235...
# [boxscores_loader] (220) Fetching boxscores for GAME_ID=0022300225...
# [boxscores_loader] (221) Fetching boxscores for GAME_ID=0022300051...
# [boxscores_loader] (222) Fetching boxscores for GAME_ID=0022300049...
# [boxscores_loader] (223) Fetching boxscores for GAME_ID=0022300050...
# [boxscores_loader] (224) Fetching boxscores for GAME_ID=0022300043...
# [boxscores_loader] (225) Fetching boxscores for GAME_ID=0022300047...
# [boxscores_loader] (226) Fetching boxscores for GAME_ID=0022300046...
# [boxscores_loader] (227) Fetching boxscores for GAME_ID=0022300048...
# [boxscores_loader] (228) Fetching boxscores for GAME_ID=0022300052...
# [boxscores_loader] (229) Fetching boxscores for GAME_ID=0022300045...
# [boxscores_loader] (230) Fetching boxscores for GAME_ID=0022300044...
# [boxscores_loader] (231) Fetching boxscores for GAME_ID=0022300242...
# [boxscores_loader] (232) Fetching boxscores for GAME_ID=0022300244...
# [boxscores_loader] (233) Fetching boxscores for GAME_ID=0022300240...
# [boxscores_loader] (234) Fetching boxscores for GAME_ID=0022300239...
# [boxscores_loader] (235) Fetching boxscores for GAME_ID=0022300241...
# [boxscores_loader] (236) Fetching boxscores for GAME_ID=0022300243...
# [boxscores_loader] (237) Fetching boxscores for GAME_ID=0022300246...
# [boxscores_loader] (238) Fetching boxscores for GAME_ID=0022300252...
# [boxscores_loader] (239) Fetching boxscores for GAME_ID=0022300245...
# [boxscores_loader] (240) Fetching boxscores for GAME_ID=0022300249...
# [boxscores_loader] (241) Fetching boxscores for GAME_ID=0022300251...
# [boxscores_loader] (242) Fetching boxscores for GAME_ID=0022300250...
# [boxscores_loader] (243) Fetching boxscores for GAME_ID=0022300247...
# [boxscores_loader] (244) Fetching boxscores for GAME_ID=0022300248...
# [boxscores_loader] (245) Fetching boxscores for GAME_ID=0022300257...
# [boxscores_loader] (246) Fetching boxscores for GAME_ID=0022300255...
# [boxscores_loader] (247) Fetching boxscores for GAME_ID=0022300256...
# [boxscores_loader] (248) Fetching boxscores for GAME_ID=0022300253...
# [boxscores_loader] (249) Fetching boxscores for GAME_ID=0022300254...
# [boxscores_loader] (250) Fetching boxscores for GAME_ID=0022300053...
# [boxscores_loader] (251) Fetching boxscores for GAME_ID=0022300056...
# [boxscores_loader] (252) Fetching boxscores for GAME_ID=0022300060...
# [boxscores_loader] (253) Fetching boxscores for GAME_ID=0022300055...
# [boxscores_loader] (254) Fetching boxscores for GAME_ID=0022300059...
# [boxscores_loader] (255) Fetching boxscores for GAME_ID=0022300058...
# [boxscores_loader] (256) Fetching boxscores for GAME_ID=0022300054...
# [boxscores_loader] (257) Fetching boxscores for GAME_ID=0022300057...
# [boxscores_loader] (258) Fetching boxscores for GAME_ID=0022300264...
# [boxscores_loader] (259) Fetching boxscores for GAME_ID=0022300261...
# [boxscores_loader] (260) Fetching boxscores for GAME_ID=0022300262...
# [boxscores_loader] (261) Fetching boxscores for GAME_ID=0022300263...
# [boxscores_loader] (262) Fetching boxscores for GAME_ID=0022300260...
# [boxscores_loader] (263) Fetching boxscores for GAME_ID=0022300258...
# [boxscores_loader] (264) Fetching boxscores for GAME_ID=0022300259...
# [boxscores_loader] (265) Fetching boxscores for GAME_ID=0022300265...
# [boxscores_loader] (266) Fetching boxscores for GAME_ID=0022300270...
# [boxscores_loader] (267) Fetching boxscores for GAME_ID=0022300272...
# [boxscores_loader] (268) Fetching boxscores for GAME_ID=0022300269...
# [boxscores_loader] (269) Fetching boxscores for GAME_ID=0022300273...
# [boxscores_loader] (270) Fetching boxscores for GAME_ID=0022300267...
# [boxscores_loader] (271) Fetching boxscores for GAME_ID=0022300266...
# [boxscores_loader] (272) Fetching boxscores for GAME_ID=0022300268...
# [boxscores_loader] (273) Fetching boxscores for GAME_ID=0022300271...
# [boxscores_loader] (274) Fetching boxscores for GAME_ID=0022300275...
# [boxscores_loader] (275) Fetching boxscores for GAME_ID=0022300278...
# [boxscores_loader] (276) Fetching boxscores for GAME_ID=0022300277...
# [boxscores_loader] (277) Fetching boxscores for GAME_ID=0022300274...
# [boxscores_loader] (278) Fetching boxscores for GAME_ID=0022300279...
# [boxscores_loader] (279) Fetching boxscores for GAME_ID=0022300276...
# [boxscores_loader] (280) Fetching boxscores for GAME_ID=0022300285...
# [boxscores_loader] (281) Fetching boxscores for GAME_ID=0022300280...
# [boxscores_loader] (282) Fetching boxscores for GAME_ID=0022300291...
# [boxscores_loader] (283) Fetching boxscores for GAME_ID=0022300284...
# [boxscores_loader] (284) Fetching boxscores for GAME_ID=0022300290...
# [boxscores_loader] (285) Fetching boxscores for GAME_ID=0022300281...
# [boxscores_loader] (286) Fetching boxscores for GAME_ID=0022300286...
# [boxscores_loader] (287) Fetching boxscores for GAME_ID=0022300282...
# [boxscores_loader] (288) Fetching boxscores for GAME_ID=0022300288...
# [boxscores_loader] (289) Fetching boxscores for GAME_ID=0022300289...
# [boxscores_loader] (290) Fetching boxscores for GAME_ID=0022300283...
# [boxscores_loader] (291) Fetching boxscores for GAME_ID=0022300287...
# [boxscores_loader] (292) Fetching boxscores for GAME_ID=0022301202...
# [boxscores_loader] (293) Fetching boxscores for GAME_ID=0022301204...
# [boxscores_loader] (294) Fetching boxscores for GAME_ID=0022301201...
# [boxscores_loader] (295) Fetching boxscores for GAME_ID=0022301203...
# [boxscores_loader] (296) Fetching boxscores for GAME_ID=0022301205...
# [boxscores_loader] (297) Fetching boxscores for GAME_ID=0022301214...
# [boxscores_loader] (298) Fetching boxscores for GAME_ID=0022301210...
# [boxscores_loader] (299) Fetching boxscores for GAME_ID=0022301207...
# [boxscores_loader] (300) Fetching boxscores for GAME_ID=0022301206...
# [boxscores_loader] (301) Fetching boxscores for GAME_ID=0022301209...
# [boxscores_loader] ERROR for GAME_ID=0022301209: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (302) Fetching boxscores for GAME_ID=0022301213...
# [boxscores_loader] ERROR for GAME_ID=0022301213: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (303) Fetching boxscores for GAME_ID=0022301215...
# [boxscores_loader] ERROR for GAME_ID=0022301215: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (304) Fetching boxscores for GAME_ID=0022301208...
# [boxscores_loader] ERROR for GAME_ID=0022301208: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (305) Fetching boxscores for GAME_ID=0022301211...
# [boxscores_loader] ERROR for GAME_ID=0022301211: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (306) Fetching boxscores for GAME_ID=0022301212...
# [boxscores_loader] ERROR for GAME_ID=0022301212: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (307) Fetching boxscores for GAME_ID=0022301229...
# [boxscores_loader] ERROR for GAME_ID=0022301229: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (308) Fetching boxscores for GAME_ID=0022301230...
# [boxscores_loader] ERROR for GAME_ID=0022301230: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (309) Fetching boxscores for GAME_ID=0022301227...
# [boxscores_loader] ERROR for GAME_ID=0022301227: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (310) Fetching boxscores for GAME_ID=0022301224...
# [boxscores_loader] ERROR for GAME_ID=0022301224: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (311) Fetching boxscores for GAME_ID=0022301220...
# [boxscores_loader] ERROR for GAME_ID=0022301220: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (312) Fetching boxscores for GAME_ID=0022301218...
# [boxscores_loader] ERROR for GAME_ID=0022301218: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (313) Fetching boxscores for GAME_ID=0022301228...
# [boxscores_loader] ERROR for GAME_ID=0022301228: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (314) Fetching boxscores for GAME_ID=0022301226...
# [boxscores_loader] ERROR for GAME_ID=0022301226: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (315) Fetching boxscores for GAME_ID=0022301223...
# [boxscores_loader] ERROR for GAME_ID=0022301223: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (316) Fetching boxscores for GAME_ID=0022301225...
# [boxscores_loader] ERROR for GAME_ID=0022301225: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (317) Fetching boxscores for GAME_ID=0022301221...
# [boxscores_loader] ERROR for GAME_ID=0022301221: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (318) Fetching boxscores for GAME_ID=0022301219...
# [boxscores_loader] ERROR for GAME_ID=0022301219: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (319) Fetching boxscores for GAME_ID=0022301217...
# [boxscores_loader] ERROR for GAME_ID=0022301217: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (320) Fetching boxscores for GAME_ID=0022301222...
# [boxscores_loader] ERROR for GAME_ID=0022301222: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (321) Fetching boxscores for GAME_ID=0022301216...
# [boxscores_loader] ERROR for GAME_ID=0022301216: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (322) Fetching boxscores for GAME_ID=0022300296...
# [boxscores_loader] ERROR for GAME_ID=0022300296: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (323) Fetching boxscores for GAME_ID=0022300301...
# [boxscores_loader] ERROR for GAME_ID=0022300301: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (324) Fetching boxscores for GAME_ID=0022300298...
# [boxscores_loader] ERROR for GAME_ID=0022300298: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (325) Fetching boxscores for GAME_ID=0022300300...
# [boxscores_loader] ERROR for GAME_ID=0022300300: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (326) Fetching boxscores for GAME_ID=0022300303...
# [boxscores_loader] ERROR for GAME_ID=0022300303: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (327) Fetching boxscores for GAME_ID=0022300292...
# [boxscores_loader] ERROR for GAME_ID=0022300292: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (328) Fetching boxscores for GAME_ID=0022300304...
# [boxscores_loader] ERROR for GAME_ID=0022300304: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (329) Fetching boxscores for GAME_ID=0022300297...
# [boxscores_loader] ERROR for GAME_ID=0022300297: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (330) Fetching boxscores for GAME_ID=0022300294...
# [boxscores_loader] ERROR for GAME_ID=0022300294: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (331) Fetching boxscores for GAME_ID=0022300295...
# [boxscores_loader] ERROR for GAME_ID=0022300295: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (332) Fetching boxscores for GAME_ID=0022300302...
# [boxscores_loader] ERROR for GAME_ID=0022300302: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (333) Fetching boxscores for GAME_ID=0022300299...
# [boxscores_loader] ERROR for GAME_ID=0022300299: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (334) Fetching boxscores for GAME_ID=0022300293...
# [boxscores_loader] ERROR for GAME_ID=0022300293: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (335) Fetching boxscores for GAME_ID=0022300305...
# [boxscores_loader] ERROR for GAME_ID=0022300305: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (336) Fetching boxscores for GAME_ID=0022300309...
# [boxscores_loader] ERROR for GAME_ID=0022300309: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (337) Fetching boxscores for GAME_ID=0022300308...
# [boxscores_loader] ERROR for GAME_ID=0022300308: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (338) Fetching boxscores for GAME_ID=0022300306...
# [boxscores_loader] ERROR for GAME_ID=0022300306: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (339) Fetching boxscores for GAME_ID=0022300307...
# [boxscores_loader] ERROR for GAME_ID=0022300307: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (340) Fetching boxscores for GAME_ID=0022300312...
# [boxscores_loader] ERROR for GAME_ID=0022300312: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (341) Fetching boxscores for GAME_ID=0022300315...
# [boxscores_loader] ERROR for GAME_ID=0022300315: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (342) Fetching boxscores for GAME_ID=0022300316...
# [boxscores_loader] ERROR for GAME_ID=0022300316: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (343) Fetching boxscores for GAME_ID=0022300318...
# [boxscores_loader] ERROR for GAME_ID=0022300318: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (344) Fetching boxscores for GAME_ID=0022300311...
# [boxscores_loader] ERROR for GAME_ID=0022300311: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (345) Fetching boxscores for GAME_ID=0022300310...
# [boxscores_loader] ERROR for GAME_ID=0022300310: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (346) Fetching boxscores for GAME_ID=0022300314...
# [boxscores_loader] ERROR for GAME_ID=0022300314: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (347) Fetching boxscores for GAME_ID=0022300317...
# [boxscores_loader] ERROR for GAME_ID=0022300317: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (348) Fetching boxscores for GAME_ID=0022300313...
# [boxscores_loader] ERROR for GAME_ID=0022300313: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (349) Fetching boxscores for GAME_ID=0022300322...
# [boxscores_loader] ERROR for GAME_ID=0022300322: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (350) Fetching boxscores for GAME_ID=0022300320...
# [boxscores_loader] ERROR for GAME_ID=0022300320: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (351) Fetching boxscores for GAME_ID=0022300323...
# [boxscores_loader] ERROR for GAME_ID=0022300323: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (352) Fetching boxscores for GAME_ID=0022300324...
# [boxscores_loader] ERROR for GAME_ID=0022300324: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (353) Fetching boxscores for GAME_ID=0022300319...
# [boxscores_loader] ERROR for GAME_ID=0022300319: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (354) Fetching boxscores for GAME_ID=0022300321...
# [boxscores_loader] ERROR for GAME_ID=0022300321: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (355) Fetching boxscores for GAME_ID=0022300325...
# [boxscores_loader] ERROR for GAME_ID=0022300325: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (356) Fetching boxscores for GAME_ID=0022300329...
# [boxscores_loader] ERROR for GAME_ID=0022300329: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (357) Fetching boxscores for GAME_ID=0022300327...
# [boxscores_loader] ERROR for GAME_ID=0022300327: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (358) Fetching boxscores for GAME_ID=0022300331...
# [boxscores_loader] ERROR for GAME_ID=0022300331: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (359) Fetching boxscores for GAME_ID=0022300330...
# [boxscores_loader] ERROR for GAME_ID=0022300330: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (360) Fetching boxscores for GAME_ID=0022300333...
# [boxscores_loader] ERROR for GAME_ID=0022300333: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (361) Fetching boxscores for GAME_ID=0022300332...
# [boxscores_loader] ERROR for GAME_ID=0022300332: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (362) Fetching boxscores for GAME_ID=0022300328...
# [boxscores_loader] ERROR for GAME_ID=0022300328: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (363) Fetching boxscores for GAME_ID=0022300326...
# [boxscores_loader] ERROR for GAME_ID=0022300326: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (364) Fetching boxscores for GAME_ID=0022300340...
# [boxscores_loader] ERROR for GAME_ID=0022300340: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (365) Fetching boxscores for GAME_ID=0022300339...
# [boxscores_loader] ERROR for GAME_ID=0022300339: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (366) Fetching boxscores for GAME_ID=0022300343...
# [boxscores_loader] ERROR for GAME_ID=0022300343: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (367) Fetching boxscores for GAME_ID=0022300338...
# [boxscores_loader] ERROR for GAME_ID=0022300338: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (368) Fetching boxscores for GAME_ID=0022300336...
# [boxscores_loader] ERROR for GAME_ID=0022300336: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (369) Fetching boxscores for GAME_ID=0022300337...
# [boxscores_loader] ERROR for GAME_ID=0022300337: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (370) Fetching boxscores for GAME_ID=0022300334...
# [boxscores_loader] ERROR for GAME_ID=0022300334: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (371) Fetching boxscores for GAME_ID=0022300341...
# [boxscores_loader] ERROR for GAME_ID=0022300341: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (372) Fetching boxscores for GAME_ID=0022300342...
# [boxscores_loader] ERROR for GAME_ID=0022300342: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (373) Fetching boxscores for GAME_ID=0022300335...
# [boxscores_loader] ERROR for GAME_ID=0022300335: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (374) Fetching boxscores for GAME_ID=0022300344...
# [boxscores_loader] ERROR for GAME_ID=0022300344: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (375) Fetching boxscores for GAME_ID=0022300348...
# [boxscores_loader] ERROR for GAME_ID=0022300348: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (376) Fetching boxscores for GAME_ID=0022300345...
# [boxscores_loader] ERROR for GAME_ID=0022300345: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (377) Fetching boxscores for GAME_ID=0022300346...
# [boxscores_loader] ERROR for GAME_ID=0022300346: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (378) Fetching boxscores for GAME_ID=0022300347...
# [boxscores_loader] ERROR for GAME_ID=0022300347: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (379) Fetching boxscores for GAME_ID=0022300352...
# [boxscores_loader] ERROR for GAME_ID=0022300352: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (380) Fetching boxscores for GAME_ID=0022300351...
# [boxscores_loader] ERROR for GAME_ID=0022300351: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (381) Fetching boxscores for GAME_ID=0022300354...
# [boxscores_loader] ERROR for GAME_ID=0022300354: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (382) Fetching boxscores for GAME_ID=0022300349...
# [boxscores_loader] ERROR for GAME_ID=0022300349: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (383) Fetching boxscores for GAME_ID=0022300356...
# [boxscores_loader] ERROR for GAME_ID=0022300356: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (384) Fetching boxscores for GAME_ID=0022300359...
# [boxscores_loader] ERROR for GAME_ID=0022300359: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (385) Fetching boxscores for GAME_ID=0022300353...
# [boxscores_loader] ERROR for GAME_ID=0022300353: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (386) Fetching boxscores for GAME_ID=0022300350...
# [boxscores_loader] ERROR for GAME_ID=0022300350: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (387) Fetching boxscores for GAME_ID=0022300358...
# [boxscores_loader] ERROR for GAME_ID=0022300358: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (388) Fetching boxscores for GAME_ID=0022300355...
# [boxscores_loader] ERROR for GAME_ID=0022300355: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (389) Fetching boxscores for GAME_ID=0022300357...
# [boxscores_loader] ERROR for GAME_ID=0022300357: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (390) Fetching boxscores for GAME_ID=0022300362...
# [boxscores_loader] ERROR for GAME_ID=0022300362: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (391) Fetching boxscores for GAME_ID=0022300363...
# [boxscores_loader] ERROR for GAME_ID=0022300363: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (392) Fetching boxscores for GAME_ID=0022300360...
# [boxscores_loader] ERROR for GAME_ID=0022300360: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (393) Fetching boxscores for GAME_ID=0022300361...
# [boxscores_loader] ERROR for GAME_ID=0022300361: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (394) Fetching boxscores for GAME_ID=0022300364...
# [boxscores_loader] ERROR for GAME_ID=0022300364: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (395) Fetching boxscores for GAME_ID=0022300370...
# [boxscores_loader] ERROR for GAME_ID=0022300370: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (396) Fetching boxscores for GAME_ID=0022300371...
# [boxscores_loader] ERROR for GAME_ID=0022300371: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (397) Fetching boxscores for GAME_ID=0022300368...
# [boxscores_loader] ERROR for GAME_ID=0022300368: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (398) Fetching boxscores for GAME_ID=0022300365...
# [boxscores_loader] ERROR for GAME_ID=0022300365: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (399) Fetching boxscores for GAME_ID=0022300372...
# [boxscores_loader] ERROR for GAME_ID=0022300372: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (400) Fetching boxscores for GAME_ID=0022300366...
# [boxscores_loader] ERROR for GAME_ID=0022300366: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (401) Fetching boxscores for GAME_ID=0022300367...
# [boxscores_loader] ERROR for GAME_ID=0022300367: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (402) Fetching boxscores for GAME_ID=0022300373...
# [boxscores_loader] ERROR for GAME_ID=0022300373: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (403) Fetching boxscores for GAME_ID=0022300369...
# [boxscores_loader] ERROR for GAME_ID=0022300369: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (404) Fetching boxscores for GAME_ID=0022300376...
# [boxscores_loader] ERROR for GAME_ID=0022300376: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (405) Fetching boxscores for GAME_ID=0022300378...
# [boxscores_loader] ERROR for GAME_ID=0022300378: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (406) Fetching boxscores for GAME_ID=0022300381...
# [boxscores_loader] ERROR for GAME_ID=0022300381: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (407) Fetching boxscores for GAME_ID=0022300379...
# [boxscores_loader] ERROR for GAME_ID=0022300379: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (408) Fetching boxscores for GAME_ID=0022300374...
# [boxscores_loader] ERROR for GAME_ID=0022300374: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (409) Fetching boxscores for GAME_ID=0022300375...
# [boxscores_loader] ERROR for GAME_ID=0022300375: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (410) Fetching boxscores for GAME_ID=0022300380...
# [boxscores_loader] ERROR for GAME_ID=0022300380: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (411) Fetching boxscores for GAME_ID=0022300377...
# [boxscores_loader] ERROR for GAME_ID=0022300377: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (412) Fetching boxscores for GAME_ID=0022300386...
# [boxscores_loader] ERROR for GAME_ID=0022300386: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (413) Fetching boxscores for GAME_ID=0022300385...
# [boxscores_loader] ERROR for GAME_ID=0022300385: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (414) Fetching boxscores for GAME_ID=0022300384...
# [boxscores_loader] ERROR for GAME_ID=0022300384: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (415) Fetching boxscores for GAME_ID=0022300383...
# [boxscores_loader] ERROR for GAME_ID=0022300383: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (416) Fetching boxscores for GAME_ID=0022300382...
# [boxscores_loader] ERROR for GAME_ID=0022300382: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (417) Fetching boxscores for GAME_ID=0022300387...
# [boxscores_loader] ERROR for GAME_ID=0022300387: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (418) Fetching boxscores for GAME_ID=0022300396...
# ...
# [boxscores_loader] (1145) Fetching boxscores for GAME_ID=0022301123...
# [boxscores_loader] ERROR for GAME_ID=0022301123: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1146) Fetching boxscores for GAME_ID=0022301119...
# [boxscores_loader] ERROR for GAME_ID=0022301119: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1147) Fetching boxscores for GAME_ID=0022301122...
# [boxscores_loader] ERROR for GAME_ID=0022301122: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1148) Fetching boxscores for GAME_ID=0022301116...
# [boxscores_loader] ERROR for GAME_ID=0022301116: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1149) Fetching boxscores for GAME_ID=0022301125...
# [boxscores_loader] ERROR for GAME_ID=0022301125: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1150) Fetching boxscores for GAME_ID=0022301121...
# [boxscores_loader] ERROR for GAME_ID=0022301121: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1151) Fetching boxscores for GAME_ID=0022301117...
# [boxscores_loader] ERROR for GAME_ID=0022301117: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1152) Fetching boxscores for GAME_ID=0022301118...
# [boxscores_loader] ERROR for GAME_ID=0022301118: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1153) Fetching boxscores for GAME_ID=0022301097...
# [boxscores_loader] ERROR for GAME_ID=0022301097: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1154) Fetching boxscores for GAME_ID=0022301120...
# [boxscores_loader] ERROR for GAME_ID=0022301120: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1155) Fetching boxscores for GAME_ID=0022301126...
# [boxscores_loader] ERROR for GAME_ID=0022301126: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1156) Fetching boxscores for GAME_ID=0022301115...
# [boxscores_loader] ERROR for GAME_ID=0022301115: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1157) Fetching boxscores for GAME_ID=0022301127...
# [boxscores_loader] ERROR for GAME_ID=0022301127: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1158) Fetching boxscores for GAME_ID=0022301128...
# [boxscores_loader] ERROR for GAME_ID=0022301128: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1159) Fetching boxscores for GAME_ID=0022301129...
# [boxscores_loader] ERROR for GAME_ID=0022301129: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1160) Fetching boxscores for GAME_ID=0022301130...
# [boxscores_loader] ERROR for GAME_ID=0022301130: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1161) Fetching boxscores for GAME_ID=0022301134...
# [boxscores_loader] ERROR for GAME_ID=0022301134: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1162) Fetching boxscores for GAME_ID=0022301131...
# [boxscores_loader] ERROR for GAME_ID=0022301131: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1163) Fetching boxscores for GAME_ID=0022301142...
# [boxscores_loader] ERROR for GAME_ID=0022301142: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1164) Fetching boxscores for GAME_ID=0022301132...
# [boxscores_loader] ERROR for GAME_ID=0022301132: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1165) Fetching boxscores for GAME_ID=0022301139...
# [boxscores_loader] ERROR for GAME_ID=0022301139: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1166) Fetching boxscores for GAME_ID=0022301141...
# [boxscores_loader] ERROR for GAME_ID=0022301141: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1167) Fetching boxscores for GAME_ID=0022301136...
# [boxscores_loader] ERROR for GAME_ID=0022301136: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1168) Fetching boxscores for GAME_ID=0022301138...
# [boxscores_loader] ERROR for GAME_ID=0022301138: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1169) Fetching boxscores for GAME_ID=0022301137...
# [boxscores_loader] ERROR for GAME_ID=0022301137: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1170) Fetching boxscores for GAME_ID=0022301143...
# [boxscores_loader] ERROR for GAME_ID=0022301143: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1171) Fetching boxscores for GAME_ID=0022301133...
# [boxscores_loader] ERROR for GAME_ID=0022301133: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1172) Fetching boxscores for GAME_ID=0022301140...
# [boxscores_loader] ERROR for GAME_ID=0022301140: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1173) Fetching boxscores for GAME_ID=0022301135...
# [boxscores_loader] ERROR for GAME_ID=0022301135: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1174) Fetching boxscores for GAME_ID=0022301149...
# [boxscores_loader] ERROR for GAME_ID=0022301149: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1175) Fetching boxscores for GAME_ID=0022301150...
# [boxscores_loader] ERROR for GAME_ID=0022301150: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1176) Fetching boxscores for GAME_ID=0022301145...
# [boxscores_loader] ERROR for GAME_ID=0022301145: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1177) Fetching boxscores for GAME_ID=0022301156...
# [boxscores_loader] ERROR for GAME_ID=0022301156: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1178) Fetching boxscores for GAME_ID=0022301144...
# [boxscores_loader] ERROR for GAME_ID=0022301144: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1179) Fetching boxscores for GAME_ID=0022301147...
# [boxscores_loader] ERROR for GAME_ID=0022301147: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1180) Fetching boxscores for GAME_ID=0022301155...
# [boxscores_loader] ERROR for GAME_ID=0022301155: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1181) Fetching boxscores for GAME_ID=0022301148...
# [boxscores_loader] ERROR for GAME_ID=0022301148: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1182) Fetching boxscores for GAME_ID=0022301152...
# [boxscores_loader] ERROR for GAME_ID=0022301152: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1183) Fetching boxscores for GAME_ID=0022301157...
# [boxscores_loader] ERROR for GAME_ID=0022301157: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1184) Fetching boxscores for GAME_ID=0022301153...
# [boxscores_loader] ERROR for GAME_ID=0022301153: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1185) Fetching boxscores for GAME_ID=0022301146...
# [boxscores_loader] ERROR for GAME_ID=0022301146: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1186) Fetching boxscores for GAME_ID=0022301154...
# [boxscores_loader] ERROR for GAME_ID=0022301154: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1187) Fetching boxscores for GAME_ID=0022301151...
# [boxscores_loader] ERROR for GAME_ID=0022301151: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1188) Fetching boxscores for GAME_ID=0022301159...
# [boxscores_loader] ERROR for GAME_ID=0022301159: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1189) Fetching boxscores for GAME_ID=0022301158...
# [boxscores_loader] ERROR for GAME_ID=0022301158: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1190) Fetching boxscores for GAME_ID=0022301161...
# [boxscores_loader] ERROR for GAME_ID=0022301161: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1191) Fetching boxscores for GAME_ID=0022301164...
# [boxscores_loader] ERROR for GAME_ID=0022301164: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1192) Fetching boxscores for GAME_ID=0022301165...
# [boxscores_loader] ERROR for GAME_ID=0022301165: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1193) Fetching boxscores for GAME_ID=0022301162...
# [boxscores_loader] ERROR for GAME_ID=0022301162: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1194) Fetching boxscores for GAME_ID=0022301160...
# [boxscores_loader] ERROR for GAME_ID=0022301160: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1195) Fetching boxscores for GAME_ID=0022301163...
# [boxscores_loader] ERROR for GAME_ID=0022301163: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1196) Fetching boxscores for GAME_ID=0022301167...
# [boxscores_loader] ERROR for GAME_ID=0022301167: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1197) Fetching boxscores for GAME_ID=0022301170...
# [boxscores_loader] ERROR for GAME_ID=0022301170: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1198) Fetching boxscores for GAME_ID=0022301166...
# [boxscores_loader] ERROR for GAME_ID=0022301166: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1199) Fetching boxscores for GAME_ID=0022301169...
# [boxscores_loader] ERROR for GAME_ID=0022301169: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1200) Fetching boxscores for GAME_ID=0022301168...
# [boxscores_loader] ERROR for GAME_ID=0022301168: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1201) Fetching boxscores for GAME_ID=0022301184...
# [boxscores_loader] ERROR for GAME_ID=0022301184: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1202) Fetching boxscores for GAME_ID=0022301176...
# [boxscores_loader] ERROR for GAME_ID=0022301176: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1203) Fetching boxscores for GAME_ID=0022301175...
# [boxscores_loader] ERROR for GAME_ID=0022301175: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1204) Fetching boxscores for GAME_ID=0022301183...
# [boxscores_loader] ERROR for GAME_ID=0022301183: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1205) Fetching boxscores for GAME_ID=0022301185...
# [boxscores_loader] ERROR for GAME_ID=0022301185: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1206) Fetching boxscores for GAME_ID=0022301180...
# [boxscores_loader] ERROR for GAME_ID=0022301180: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1207) Fetching boxscores for GAME_ID=0022301172...
# [boxscores_loader] ERROR for GAME_ID=0022301172: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1208) Fetching boxscores for GAME_ID=0022301173...
# [boxscores_loader] ERROR for GAME_ID=0022301173: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1209) Fetching boxscores for GAME_ID=0022301174...
# [boxscores_loader] ERROR for GAME_ID=0022301174: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1210) Fetching boxscores for GAME_ID=0022301182...
# [boxscores_loader] ERROR for GAME_ID=0022301182: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1211) Fetching boxscores for GAME_ID=0022301178...
# [boxscores_loader] ERROR for GAME_ID=0022301178: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1212) Fetching boxscores for GAME_ID=0022301171...
# [boxscores_loader] ERROR for GAME_ID=0022301171: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1213) Fetching boxscores for GAME_ID=0022301177...
# [boxscores_loader] ERROR for GAME_ID=0022301177: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1214) Fetching boxscores for GAME_ID=0022301181...
# [boxscores_loader] ERROR for GAME_ID=0022301181: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [boxscores_loader] (1215) Fetching boxscores for GAME_ID=0022301179...
# [boxscores_loader] ERROR for GAME_ID=0022301179: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
# [boxscores_loader] (1216) Fetching boxscores for GAME_ID=0022301198...
# KeyboardInterrupt

# %%
import numpy as np

df = trad_df.copy()

# Figure out the points column name
if "points" in df.columns:
    pts_col = "points"
elif "PTS" in df.columns:
    pts_col = "PTS"
else:
    raise ValueError("Could not find a points column in trad_df (expected 'points' or 'PTS').")

# Minutes might be "minutes" as 'MM:SS' or already numeric
min_col = "minutes" if "minutes" in df.columns else None
if min_col is None:
    raise ValueError("Could not find a 'minutes' column in trad_df.")

player_games = df[["GAME_ID", "TEAM_ID", "PLAYER_ID", "firstName", "familyName", pts_col, min_col]].copy()
player_games = player_games.rename(columns={pts_col: "POINTS", min_col: "MIN_RAW"})

# Build a simple name for convenience
player_games["PLAYER_NAME"] = player_games["firstName"].astype(str) + " " + player_games["familyName"].astype(str)

# Convert minutes "MM:SS" to float minutes
def parse_minutes(m):
    if isinstance(m, (int, float, np.number)):
        return float(m)
    if isinstance(m, str):
        if ":" in m:
            mm, ss = m.split(":")
            try:
                return float(mm) + float(ss) / 60.0
            except ValueError:
                return np.nan
        try:
            return float(m)
        except ValueError:
            return np.nan
    return np.nan

player_games["MINUTES"] = player_games["MIN_RAW"].apply(parse_minutes)

# Filter out players with 0 minutes or missing minutes
player_games = player_games[player_games["MINUTES"].notna() & (player_games["MINUTES"] > 0)].copy()

# Ensure GAME_ID is string to match games_df
player_games["GAME_ID"] = player_games["GAME_ID"].astype(str)
player_games["TEAM_ID"] = player_games["TEAM_ID"].astype(int)
player_games["PLAYER_ID"] = player_games["PLAYER_ID"].astype(int)

print("player_games shape:", player_games.shape)
display(player_games.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 18
#      15 if min_col is None:
#      16     raise ValueError("Could not find a 'minutes' column in trad_df.")
# ---> 18 player_games = df[["GAME_ID", "TEAM_ID", "PLAYER_ID", "firstName", "familyName", pts_col, min_col]].copy()
#      19 player_games = player_games.rename(columns={pts_col: "POINTS", min_col: "MIN_RAW"})
#      21 # Build a simple name for convenience
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['TEAM_ID', 'PLAYER_ID'] not in index"

# %%
# Figure out team points column
if "PTS" in team_games.columns:
    team_pts_col = "PTS"
elif "TEAM_POINTS" in team_games.columns:
    team_pts_col = "TEAM_POINTS"
else:
    raise ValueError("team_games must contain 'PTS' or 'TEAM_POINTS'.")

team_pts = team_games[["GAME_ID", "TEAM_ID", team_pts_col]].copy()
team_pts = team_pts.rename(columns={team_pts_col: "TEAM_POINTS"})

# Make sure GAME_ID is string to match player_games
team_pts["GAME_ID"] = team_pts["GAME_ID"].astype(str)
team_pts["TEAM_ID"] = team_pts["TEAM_ID"].astype(int)

player_games = player_games.merge(
    team_pts,
    on=["GAME_ID", "TEAM_ID"],
    how="left",
)

print("After merge, player_games shape:", player_games.shape)
display(player_games.head())

# Compute per-game share of team points
player_games["POINTS"] = player_games["POINTS"].astype(float)
player_games["TEAM_POINTS"] = player_games["TEAM_POINTS"].astype(float)

# Avoid divide-by-zero
player_games["PTS_SHARE"] = np.where(
    player_games["TEAM_POINTS"] > 0,
    player_games["POINTS"] / player_games["TEAM_POINTS"],
    0.0,
)

display(player_games.head())

# %%
group_cols = ["PLAYER_ID", "TEAM_ID", "PLAYER_NAME"]

agg_player = (
    player_games.groupby(group_cols)
    .agg(
        GAMES_PLAYED=("GAME_ID", "nunique"),
        TOTAL_POINTS=("POINTS", "sum"),
        TOTAL_MINUTES=("MINUTES", "sum"),
        MEAN_POINTS=("POINTS", "mean"),
        MEAN_MINUTES=("MINUTES", "mean"),
        MEAN_PTS_SHARE=("PTS_SHARE", "mean"),
    )
    .reset_index()
)

print("agg_player shape (before filters):", agg_player.shape)
display(agg_player.head())

# %%
# Simple filters to keep players with some real sample size
min_games = 10     # tweak if you like
min_minutes = 100  # total minutes over season

mask = (agg_player["GAMES_PLAYED"] >= min_games) & (agg_player["TOTAL_MINUTES"] >= min_minutes)
player_lambdas = agg_player[mask].copy()

print("player_lambdas shape (after filters):", player_lambdas.shape)
display(player_lambdas.head())

# %%
# Team season average points (per game)
team_avg_pts = (
    team_pts.groupby("TEAM_ID")["TEAM_POINTS"]
    .mean()
    .rename("TEAM_MEAN_POINTS")
    .reset_index()
)

print("team_avg_pts shape:", team_avg_pts.shape)
display(team_avg_pts.head())

player_lambdas = player_lambdas.merge(
    team_avg_pts,
    on="TEAM_ID",
    how="left",
)

# λ_player v0: expected points in a "typical" game = team_avg_pts * mean share
player_lambdas["LAMBDA_POINTS_V0"] = (
    player_lambdas["TEAM_MEAN_POINTS"] * player_lambdas["MEAN_PTS_SHARE"]
)

print("player_lambdas with λ shape:", player_lambdas.shape)
display(
    player_lambdas.sort_values("LAMBDA_POINTS_V0", ascending=False).head(15)
)

# %%
out_dir = PROJECT_ROOT / "data" / "processed" / "nba"
out_dir.mkdir(parents=True, exist_ok=True)

out_path = out_dir / f"player_points_lambdas_{season}.parquet"
player_lambdas.to_parquet(out_path, index=False)

print("Saved player λ table to:", out_path)

# %%
def find_player(name_substring, df=None, top=10):
    if df is None:
        df = player_lambdas
    mask = df["PLAYER_NAME"].str.contains(name_substring, case=False, na=False)
    return df[mask].sort_values("LAMBDA_POINTS_V0", ascending=False).head(top)

print("Example: Nikola Jokic")
display(find_player("Jokic"))

print("Example: LeBron James")
display(find_player("LeBron"))

print("Example: Jayson Tatum")
display(find_player("Tatum"))
