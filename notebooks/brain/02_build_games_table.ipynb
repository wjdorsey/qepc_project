# %%
import sys
from pathlib import Path

# Assume the notebook is in: <project_root>/notebooks/brain
# Then parents[1] = <project_root>
PROJECT_ROOT = Path.cwd().resolve().parents[1]

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

print("PROJECT_ROOT:", PROJECT_ROOT)
print("qepc in root?", (PROJECT_ROOT / "qepc").exists())

# %%
from qepc.brain.games_loader import fetch_league_games, build_games_table

team_games = fetch_league_games("2023-24")  # later we can switch to "2025-26"
games = build_games_table(team_games)
games.head()
