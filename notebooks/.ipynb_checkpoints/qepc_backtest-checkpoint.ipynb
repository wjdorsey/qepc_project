# %%
# ====================================================================
# 🌌 QEPC UNIVERSAL LOADER
# ====================================================================
import sys, os
# Add the project root (one level up) to the path so we can import the context
sys.path.append(os.path.abspath('..')) 

# Load everything from the central context file
from notebook_context import * # Trigger the success message
print_ready_message()
print("="*80)

# %% [markdown]
# -------------------------------
# ----------------------------------------

# %%
# --- RUN FULL SEASON BACKTEST (Quiet Mode) ---
# This tests the 2025-2026 season up to your data cutoff (Nov 17).
# It will take a few minutes to run.

qa.qepc_step("Initializing Season Backtest...")

# Ensure these dates match your file's range
full_history_results = qa.run_season_backtest("2024-10-22", "2025-11-17")

# Save results automatically
if not full_history_results.empty:
    save_path = "data/backups/Backtest_Results_2025.csv"
    full_history_results.to_csv(save_path, index=False)
    print(f"\n💾 Results saved to: {save_path}")

# %%
import os
# Ensure the directory exists
os.makedirs("data/backups", exist_ok=True)

# Now save the results (assuming 'full_history_results' is still in memory)
if 'full_history_results' in locals() and not full_history_results.empty:
    full_history_results.to_csv("data/backups/Backtest_Results_2025.csv", index=False)
    print("✅ Results saved successfully!")
else:
    print("⚠️ Results variable lost. You may need to re-run the backtest.")
