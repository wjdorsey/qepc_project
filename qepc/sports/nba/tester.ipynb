# %%
from qepc.sports.nba.data_source import load_team_stats
df = load_team_stats()
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from qepc.sports.nba.data_source import load_team_stats
#       2 df = load_team_stats()
#       3 df.head()
#
# ModuleNotFoundError: No module named 'qepc'
